# %% [markdown]
# You can press *shift + enter* to quickly advance through each line of a notebook. Try it!

# %% [markdown]
# Check that you have a recent version of TensorFlow installed, v1.3 or higher.

# %%
import tensorflow as tf
print("You have version %s" % tf.__version__)
# Out:
# You have version 1.8.0

# %% [markdown]
# Check if Matplotlib is working. After running this cell, you should see a plot appear below.

# %%
# %matplotlib inline
import pylab
import numpy as np

# create some data using numpy. y = x * 0.1 + 0.3 + noise
x = np.random.rand(100).astype(np.float32)
noise = np.random.normal(scale=0.01, size=len(x))
y = x * 0.1 + 0.3 + noise

# plot it
pylab.plot(x, y, '.')

# %% [markdown]
# Check if Numpy and Pillow are working. After runnign this cell, you should see a random image appear below.

# %%
import PIL.Image as Image
import numpy as np
from matplotlib.pyplot import imshow

image_array = np.random.rand(200,200,3) * 255
print(image_array)
img = Image.fromarray(image_array.astype('uint8')).convert('RGBA')
imshow(np.asarray(img))
# Out:
# [[[ 84.4580067  183.34045404  57.78317609]
#   [178.90674689 221.28587374 187.98449272]
#   [ 50.22584375 197.67047691 239.60982857]
#   ...
#   [238.06900275 225.52422317  29.64056255]
#   [  0.89499791 233.96209274 228.27057498]
#   [216.21669457 160.58616335 161.9863942 ]]
#
#  [[146.98545592   5.56550583 203.31313215]
#   [180.20432318 133.74181786 117.27877081]
#   [239.05182601   9.06074748  93.34897046]
#   ...
#   [ 87.54354965 228.98118575 120.63465408]
#   [ 32.24580769 167.99183075   7.6913475 ]
#   [ 15.47152026 103.01819174 102.41701134]]
#
#  [[ 16.80044153  97.01782286 251.03889281]
#   [ 35.18417264  69.82819039 100.36218388]
#   [234.50335508  61.50790283 205.36374321]
#   ...
#   [106.09607226 136.97276812 194.65013359]
#   [210.13318988 227.59401794 132.67596408]
#   [139.52966523  81.51424163   6.91019151]]
#
#  ...
#
#  [[105.97779856 191.55950341  92.14124177]
#   [197.20183951  41.56656911 229.56375979]
#   [201.7864512  175.2268834  146.90347202]
#   ...
#   [ 57.23319791 187.38186941 137.96884322]
#   [106.60012011 134.10815495 207.83728351]
#   [  1.54893718  98.70309151  34.89049932]]
#
#  [[ 51.38251582  35.28859515 179.66495798]
#   [243.15350668  57.16676621 189.18654981]
#   [109.05531887 170.27220637  66.97560773]
#   ...
#   [  9.98958824  27.79142413 234.40654637]
#   [202.64930829   7.88000899 220.01605908]
#   [101.95916501 250.59120924  29.18772523]]
#
#  [[ 30.23888112  19.09848567 224.32556002]
#   [177.68160392  99.8025775  119.13264228]
#   [158.88186312 254.81790073  65.7354767 ]
#   ...
#   [210.48555303  56.77560481 133.95579168]
#   [117.0310959  109.12876208 202.61892842]
#   [246.60461747  15.9699392  162.38170439]]]

# %% [markdown]
# Check if Pandas is working. After running this cell, you should see a table appear below.

# %%
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
births = [968, 155, 77, 578, 973]
BabyDataSet = list(zip(names,births))
pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %% [markdown]
# That's it! You're ready to start the workshop.
